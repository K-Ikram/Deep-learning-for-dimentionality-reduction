# %% [markdown]
# # Linear Dimensionality Reduction Methods

# %%
from sklearn.datasets import make_moons
from sklearn.datasets import make_regression
from matplotlib import pyplot
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA,FactorAnalysis
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Generate linear data

# %%
X,Y=make_regression(n_samples=1000, n_features=6, n_informative=10, n_targets=1 )

# %%
linear_data = pd.DataFrame(dict(x1=X[:,0], x2=X[:,1],x3=X[:,2], x4=X[:,3], x5=X[:,4], x6=X[:,5]))

# %%
linear_data
# Out:
#            x1        x2        x3        x4        x5        x6
# 0   -0.352186  1.526176  0.358182 -2.392994  0.189100 -0.686839
# 1   -2.069670 -1.359520  0.051505 -0.918269 -1.170360  0.362378
# 2   -1.579113  0.766763 -0.282986 -1.747683 -0.071387  1.605049
# 3   -0.385767  1.461043 -0.192832  0.222389  0.313507  2.432528
# 4    2.862473  0.499961 -0.152907  1.036845 -1.253397  1.721767
# ..        ...       ...       ...       ...       ...       ...
# 995 -0.207002 -1.044629 -1.672176  0.992735  0.982379  0.275458
# 996 -2.496522 -0.487467  1.334170  0.078861 -1.140041 -0.972773
# 997  0.352978 -1.804270 -1.980102 -0.178887  0.265673  0.867673
# 998  0.915642 -1.339749  1.063866  0.029531 -0.079383  1.785549
# 999  1.401557  2.151871 -2.345571 -1.398568  1.504907  0.322790
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Principal Component Analysis

# %%
PCA= PCA(n_components=3) 
X=PCA.fit_transform(linear_data)

# %%
plt.figure(figsize=(12,8))
plt.title('PCA projection')
plt.scatter(X[:,0], X[:,1]) #blue
plt.scatter(X[:,1], X[:,2]) #orange

# %% [markdown]
# ## Factor Analysis

# %%
Factor_Analysis= FactorAnalysis(n_components=3) 
X1=Factor_Analysis.fit_transform(linear_data)

# %%
plt.figure(figsize=(12,8))
plt.title('Factor Analysis Projection')
plt.scatter(X1[:,0], X1[:,1])
plt.scatter(X1[:,1], X1[:,2])
