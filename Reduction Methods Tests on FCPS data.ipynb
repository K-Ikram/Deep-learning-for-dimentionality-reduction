# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.manifold import Isomap
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.manifold import SpectralEmbedding
from keras.layers import Input, Dense
from keras.models import Model
import numpy as np

# %% [markdown]
# ## Import FCPS data

# %%
atom=pd.read_csv("Data/atom.csv")
Chainlink=pd.read_csv("Data/Chainlink.csv")
EngyTime=pd.read_csv("Data/EngyTime.csv")
Hepta=pd.read_csv("Data/Hepta.csv")
Lsun=pd.read_csv("Data/Lsun.csv")
Target=pd.read_csv("Data/Target.csv")
Tetra=pd.read_csv("Data/Tetra.csv")
TwoDiamonds=pd.read_csv("Data/TwoDiamonds.csv")
WingNut=pd.read_csv("Data/WingNut.csv")

# %% [markdown]
# * Hepta (n = 212,var=3 classes = 7, clearly defined clusters)
# * Tetra (n = 400,var=3, classes = 4, almost touching clusters)
# * Chainlink (n = 1000,var=3 classes = 2, linearly non-separable)
# * Atom (n = 800, var=3, classes = 2, different variances and linearly nonseparable)
# * Lsun (n= 400, var=2 ,classes=3 ,different variances in clusters)
# * EngyTime(n= 4096,var=2,classes= 2 ,density defined clusters)
# * Target (n=770, var=2, classes=6, outliers)
# * TwoDiamonds (n=800,var=2,classes= 2, touching clusters)
# * WingNut(n=1070,var=2, classes=2, largest densities at cluster borders)

# %%
df_atom=atom.drop('Cls',axis=1)
df_Chainlink=Chainlink.drop('Cls',axis=1)
df_EngyTime=EngyTime.drop('Cls',axis=1)
df_Hepta=Hepta.drop('Cls',axis=1)
df_Lsun=Lsun.drop('Cls',axis=1)
df_Target=Target.drop('Cls',axis=1)
df_Tetra=Tetra.drop('Cls',axis=1)
df_TwoDiamonds=TwoDiamonds.drop('Cls',axis=1)
df_WingNut=WingNut.drop('Cls',axis=1)

# %% [markdown]
# ## ACP

# %% [markdown]
# Atom data

# %%
PCA= PCA(n_components=3) 
X=PCA.fit_transform(df_atom.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = atom ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# ChainLink data

# %%
pca = PCA(n_components=3) 
X=pca.fit_transform(df_Chainlink.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Chainlink ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# Tetra data

# %%
pca= PCA(n_components=3) 
X=pca.fit_transform(df_Tetra.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Tetra ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# Hepta data

# %%
pca= PCA(n_components=3) 
X=pca.fit_transform(df_Hepta.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Hepta ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# Lsun data

# %%
pca= PCA(n_components=2) 
X=pca.fit_transform(df_Lsun.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Lsun ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# Target data

# %%
pca= PCA(n_components=2) 
X=pca.fit_transform(df_Target.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Target['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# EngyTime data

# %%
pca= PCA(n_components=2) 
X=pca.fit_transform(df_EngyTime.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = EngyTime['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# TwoDiamonds data

# %%
pca= PCA(n_components=2) 
X=pca.fit_transform(df_TwoDiamonds.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =TwoDiamonds['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# WingNut data

# %%
pca= PCA(n_components=2) 
X=pca.fit_transform(df_WingNut.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = WingNut['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier composant principal')
plt.ylabel ('Deuxième composante principale')
# Out:
# Text(0, 0.5, 'Deuxième composante principale')

# %% [markdown]
# ## Multi-dimensional scaling (MDS)

# %% [markdown]
# Atom data

# %%
mds= MDS(n_components=3) 
X=mds.fit_transform(df_atom.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = atom ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ChainLink data

# %%
mds= MDS(n_components=3) 
X=mds.fit_transform(df_Chainlink.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Chainlink ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# EngyTime data

# %%
mds= MDS(n_components=3) 
X=mds.fit_transform(df_EngyTime.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 1], X[:, 2], c = EngyTime ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Hepta data

# %%
mds= MDS(n_components=3) 
X=mds.fit_transform(df_Hepta.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Hepta ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Lsun data

# %%
mds= MDS(n_components=2) 
X=mds.fit_transform(df_Lsun.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Lsun ['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Tetra data

# %%
mds= MDS(n_components=3) 
X=mds.fit_transform(df_Tetra.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Tetra['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Target data

# %%
mds= MDS(n_components=2) 
X=mds.fit_transform(df_Target.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = Target['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# TwoDiamonds data

# %%
mds= MDS(n_components=2) 
X=mds.fit_transform(df_TwoDiamonds.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = TwoDiamonds['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# WingNut data

# %%
mds= MDS(n_components=2) 
X=mds.fit_transform(df_WingNut.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c = WingNut['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ## Locally Linear Embedding (LLE)

# %% [markdown]
# Atom data

# %%
LLE=LocallyLinearEmbedding(n_components=3) 
X=LLE.fit_transform(df_atom.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =atom['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ChainLink data

# %%
LLE=LocallyLinearEmbedding(n_components=3) 
X=LLE.fit_transform(df_Chainlink.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Chainlink['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Hepta data

# %%
LLE=LocallyLinearEmbedding(n_components=3) 
X=LLE.fit_transform(df_Hepta.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 2], c =Hepta['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Tetra data

# %%
LLE=LocallyLinearEmbedding(n_components=3) 
X=LLE.fit_transform(df_Tetra.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Tetra['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Lsun data

# %%
LLE=LocallyLinearEmbedding(n_components=2) 
X=LLE.fit_transform(df_Lsun.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Lsun['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# EngyTime data

# %%
LLE=LocallyLinearEmbedding(n_components=2) 
X=LLE.fit_transform(df_EngyTime.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =EngyTime['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Target data

# %%
LLE=LocallyLinearEmbedding(n_components=2) 
X=LLE.fit_transform(df_Target.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Target['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# TwoDiamonds data

# %%
LLE=LocallyLinearEmbedding(n_components=2) 
X=LLE.fit_transform(df_TwoDiamonds.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =TwoDiamonds['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# WingNut data

# %%
LLE=LocallyLinearEmbedding(n_components=2) 
X=LLE.fit_transform(df_WingNut.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =WingNut['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ## Spectral Embedding (Laplacian Eigenmaps)

# %% [markdown]
# Atom data

# %%
spe=SpectralEmbedding(n_components=3) 
X=spe.fit_transform(df_atom.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =atom['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ChainLink data

# %%
spe=SpectralEmbedding(n_components=3) 
X=spe.fit_transform(df_Chainlink.values)
# Out:
# C:\Users\majda\Anaconda3\lib\site-packages\sklearn\manifold\spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Chainlink['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# EngyTime data

# %%
spe=SpectralEmbedding(n_components=2) 
X=spe.fit_transform(df_EngyTime.values)

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =EngyTime['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Hepta data

# %%
spe=SpectralEmbedding(n_components=3) 
X=spe.fit_transform(df_Hepta.values)
# Out:
# C:\Users\majda\Anaconda3\lib\site-packages\sklearn\manifold\spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Hepta['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Lsun data

# %%
spe=SpectralEmbedding(n_components=2) 
X=spe.fit_transform(df_Lsun.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Lsun['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Target data

# %%
spe=SpectralEmbedding(n_components=2) 
X=spe.fit_transform(df_Target.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Target['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Tetra data

# %%
spe=SpectralEmbedding(n_components=3) 
X=spe.fit_transform(df_Tetra.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Tetra['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# TwoDiamonds data

# %%
spe=SpectralEmbedding(n_components=2) 
X=spe.fit_transform(df_TwoDiamonds.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =TwoDiamonds['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# WingNut data

# %%
spe=SpectralEmbedding(n_components=2) 
X=spe.fit_transform(df_WingNut.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =WingNut['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ## Isometric Feature Mapping (Isomap)

# %% [markdown]
# Atom data

# %%
isomap=Isomap(n_neighbors=8,n_components=3) 
X=isomap.fit_transform(df_atom.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =atom['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ChainLink data

# %%
isomap=Isomap(n_neighbors=8,n_components=3) 
X=isomap.fit_transform(df_Chainlink.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Chainlink['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# EngyTime data

# %%
isomap=Isomap(n_neighbors=8,n_components=2) 
X=isomap.fit_transform(df_EngyTime.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =EngyTime['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Hepta data

# %%
isomap=Isomap(n_neighbors=8,n_components=3) 
X=isomap.fit_transform(df_Hepta.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Hepta['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Lsun data

# %%
isomap=Isomap(n_neighbors=8,n_components=2) 
X=isomap.fit_transform(df_Lsun.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Lsun['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Target data

# %%
isomap=Isomap(n_neighbors=8,n_components=2) 
X=isomap.fit_transform(df_Target.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Target['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# Tetra data

# %%
isomap=Isomap(n_neighbors=8,n_components=3) 
X=isomap.fit_transform(df_Tetra.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =Tetra['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# TwoDiamonds data

# %%
isomap=Isomap(n_neighbors=8,n_components=2) 
X=isomap.fit_transform(df_TwoDiamonds.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =TwoDiamonds['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# WingNut data

# %%
isomap=Isomap(n_neighbors=8,n_components=2) 
X=isomap.fit_transform(df_WingNut.values)
plt.figure (figsize = (8,6))
plt.scatter (X[:, 0], X[:, 1], c =WingNut['Cls'], cmap = 'rainbow')
plt.xlabel ('Premier plan')
plt.ylabel ('Deuxième plan')
# Out:
# Text(0, 0.5, 'Deuxième plan')

# %% [markdown]
# ## Autoencoder

# %% [markdown]
# Atom data

# %%
print(df_atom.shape)
n = df_atom.shape[0]
p = df_atom.shape[1]
# Out:
# (800, 3)

# %%
inputL = Input(shape=(p,))
hiddenL = Dense(2,activation='sigmoid')(inputL)
outputL = Dense(p,activation='linear')(hiddenL)
autoencoder = Model(inputL,outputL)

# %% [markdown]
# La variable "autoencoder" représente le réseau dans son ensemble (le modèle), commençant
# par **inputL** et finissant par **outputL**. Nous en définissons les caractéristiques d’apprentissage
# en spécifiant l’algorithme d’optimisation (optimizer = ‘adam’) et le critère à optimiser (loss =
# ‘mse’ ; mean squared error).

# %%
autoencoder.compile(optimizer='adam',loss='mse')
print(autoencoder.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 8
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 9
# ...
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
n_epochs = 1000
historique = autoencoder.fit(x=df_atom,y=df_atom,epochs=n_epochs)
# Out:
# Epoch 1/1000
# 800/800 [==============================] - 0s 225us/step - loss: 423.1896
# Epoch 2/1000
# 800/800 [==============================] - 0s 50us/step - loss: 422.7123
# Epoch 3/1000
# 800/800 [==============================] - 0s 45us/step - loss: 422.2024
# Epoch 4/1000
# 800/800 [==============================] - 0s 52us/step - loss: 421.6477
# Epoch 5/1000
# 800/800 [==============================] - 0s 45us/step - loss: 421.0164
# Epoch 6/1000
# 800/800 [==============================] - 0s 51us/step - loss: 420.3335
# Epoch 7/1000
# 800/800 [==============================] - 0s 56us/step - loss: 419.5015
# Epoch 8/1000
# 800/800 [==============================] - 0s 50us/step - loss: 418.5708
# Epoch 9/1000
# 800/800 [==============================] - 0s 52us/step - loss: 417.6487
# Epoch 10/1000
# 800/800 [==============================] - 0s 52us/step - loss: 416.6777
# Epoch 11/1000
# 800/800 [==============================] - 0s 56us/step - loss: 415.8079
# ...

# %%
plt.plot(np.arange(1,n_epochs+1),historique.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Décroissance fnct de perte')
plt.show()
